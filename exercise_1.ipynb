# %%
ice_cream_rating = 8
sleeping_rating = 9

# %%
first_name = input("Qual é o seu primeiro nome? ")
second_name = input("Qual seu sobrenome? ")
my_name = first_name + " " + second_name
# Out:
# Qual é o seu primeiro nome?  Tysson
# Qual seu sobrenome?  do Carmo

# %%
happiness_rating = (ice_cream_rating + sleeping_rating)/2

# %%
print(f'ice_cream_rating type: {type(ice_cream_rating)}, my_name type: {type(my_name)}, happiness_rating type: {type(happiness_rating)}')
# Out:
# ice_cream_rating type: <class 'int'>, my_name type: <class 'str'>, happiness_rating type: <class 'float'>

# %%
print(f"""
      My name is {first_name} and I give eating ice cream a score of {ice_cream_rating} of 10!
      I am {my_name} and my sleeping enjoyment rating is {sleeping_rating} of 10!
      Based on the factors above, my happiness rating is {happiness_rating} out of 10, or {happiness_rating * 10} %
      """)
# Out:
#       My name is Tysson and I give eating ice cream a score of 8 of 10!
#       I am Tysson do Carmo and my sleeping enjoyment rating is 9 of 10!
#       Based on the factors above, my happiness rating is 8.5 out of 10, or 85.0 %
